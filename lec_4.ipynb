# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruvtomar2006-debug/dsa_assignment/blob/main/lec_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#homework
import pandas as pd

def big_countries(world: pd.DataFrame) -> pd.DataFrame:
    return world.loc[(world['area']>=3000000)|(world['population']>=25000000),['name','population','area']]

# %%
import pandas as pd

df1 = pd.DataFrame({
    'id': [1, 2, 3, 5, 6],
    'name': ['raja', 'rani', 'dhruv', 'kiran', 'rahul'],
    'age': [25, 30, 35, 30, 39]
})

df2 = pd.DataFrame({
    'id': [9, 6, 3],      # 3 & 6 is common with df1
    'name': ['raja', 'dhori', 'amanwa'],
    'age': [20, 35, 60]
})

df3 = pd.merge(df1, df2, on='id', how='outer')

df4 = pd.merge(df1, df2, on='id', how='left')

df5 = pd.merge(df1, df2, on='id', how='right')

print(df3)
# Out:
#    id name_x  age_x  name_y  age_y
# 0   1   raja   25.0     NaN    NaN
# 1   2   rani   30.0     NaN    NaN
# 2   3  dhruv   35.0  amanwa   60.0
# 3   5  kiran   30.0     NaN    NaN
# 4   6  rahul   39.0   dhori   35.0
# 5   9    NaN    NaN    raja   20.0

# %%
# join eak ke upar chipikna h
df1 = pd.DataFrame({
    'id': [1, 2, 3, 5, 6],
    'name': ['raja', 'rani', 'dhruv', 'kiran', 'rahul'],
    'age': [25, 30, 35, 30, 39]
})

df2 = pd.DataFrame({
    'id': [9, 6, 3],      # 3 & 6 is common with df1
    'name': ['raja', 'dhori', 'amanwa'],
    'age': [20, 35, 60]
})

df3 = pd.concat([df1,df2])


display(df3)
# Out:
#    id    name  age
# 0   1    raja   25
# 1   2    rani   30
# 2   3   dhruv   35
# 3   5   kiran   30
# 4   6   rahul   39
# 0   9    raja   20
# 1   6   dhori   35
# 2   3  amanwa   60

# %%
df1 = pd.DataFrame({
    'id': [1, 2, 3, 5, 6],
    'name': ['raja', 'rani', 'dhruv', 'kiran', 'rahul'],
    'age': [25, 30, 35, 30, 39]
})

df2 = pd.DataFrame({
    'id': [9, 6, 3],      # 3 & 6 is common with df1
    'name': ['raja', 'dhori', 'amanwa'],
    'age': [20, 35, 60]
})

df3 = pd.concat([df1,df2])


df3=df3.drop_duplicates(subset=['id', 'name'])
display(df3
